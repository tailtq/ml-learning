# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('course/DATA/00-puppy.jpg')

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
gray_img = cv2.imread('course/DATA/00-puppy.jpg', cv2.IMREAD_GRAYSCALE)

# %%
# You have seen the problem that occur in the average method.
# Weighted method has a solution to that problem.
# Since red color has more wavelength of all the three colors, and green is the color that
# has not only less wavelength then red color but also green is the color that gives more soothing effect to the eyes.
# formula: (0.3 * R + 0.59 * G + 0.11 * B)
print(fix_img[0][0], gray_img[0][0])
# Out:
# [95 81 78] 85

# %%
# the idea behind choosing colormap is to find a good representation in 3D colorspace for your data set
plt.imshow(gray_img, cmap='gray')

# %%
plt.imshow(fix_img)

# %%
#new_img = cv2.resize(fix_img, (900,600))
new_img = cv2.resize(fix_img, (0,0), fx=0.5, fy=0.5)
plt.imshow(new_img)

# %%
new_img = cv2.flip(fix_img, 1)
plt.imshow(new_img)

# %%
cv2.imwrite('cool_puppy.jpg', new_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(new_img)
