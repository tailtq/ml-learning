# %% [markdown]
# ## Goals to complete:
# - Build raw neural network
# - Use Keras Resnet50
#
# ## Steps:
# 1. **Write python file to seperate images**
#     * Class 1
#         * 0.jpg
#         * 1.jpg
#         * ...
#     * Class 2
#         * 0.jpg
#         * 1.jpg
#         * ...
#     * ...
#     * Class n
# 2. **Visualize data**
# 3. **Create image generator**
# 4. **Load data**
# 5. **Create model**
# 6. **Fit model**
# 7. **Plot history**
# 8. **Check overfitting**
# 9. **Get result**
#
# ## Notes:
# - (Accuracy -- Val_accuracy) and (Loss -- Val_loss): Check overfitting
# - MaxPooling2D: Reduce image size

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2
import os

from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ### Visualize data

# %%
cat0 = cv2.imread('dataset/train/cat/cat.0.jpg')
cat0 = cv2.cvtColor(cat0, cv2.COLOR_BGR2RGB)
print(cat0.shape)

plt.imshow(cat0)
# Out:
# (374, 500, 3)

# %%
dog0 = cv2.imread('dataset/train/dog/dog.0.jpg')
dog0 = cv2.cvtColor(dog0, cv2.COLOR_BGR2RGB)
print(dog0.shape)

plt.imshow(dog0)
# Out:
# (375, 499, 3)

# %% [markdown]
# ### Create ImageDataGenerator

# %%
image_gen = ImageDataGenerator(width_shift_range=0.1,
                               height_shift_range=0.1,
                               rescale=1/255,
                               shear_range=0.2,
                               zoom_range=0.2,
                               horizontal_flip=True,
                               validation_split=0.2,
                               fill_mode='nearest')

# %%
plt.imshow(image_gen.random_transform(dog0))

# %%
plt.imshow(image_gen.random_transform(cat0))

# %% [markdown]
# ### Load data

# %%
directory = 'dataset/train'
batch_size = 32
image_shape = (127, 127, 3)

train_data = image_gen.flow_from_directory(directory,
                                          target_size=image_shape[:2],
                                          batch_size=batch_size,
                                          class_mode='categorical',
                                          subset='training')

test_data = image_gen.flow_from_directory(directory,
                                          target_size=image_shape[:2],
                                          batch_size=batch_size,
                                          class_mode='categorical',
                                          subset='validation')
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.

# %%
plt.imshow(train_data[0][0][4])

# %%
print(train_data.samples, test_data.samples)
# Out:
# 20000 5000

# %% [markdown]
# ### Create model

# %%
model = Sequential([
    Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', input_shape=image_shape),
    Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    
    Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'),
    Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    
    Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'),
    Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Flatten(),
    
    Dense(500, activation='relu'),
    Dropout(0.5),
    
    Dense(2, activation='softmax')
])

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 127, 127, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 127, 127, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 63, 63, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 63, 63, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 31, 31, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 31, 31, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15, 15, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 28800)             0
# _________________________________________________________________
# dense (Dense)                (None, 500)               14400500
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1002
# =================================================================
# Total params: 14,688,510
# Trainable params: 14,688,510
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Fit model

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
earlystop = EarlyStopping(patience=10)
callbacks = [earlystop]

# %%
results = model.fit_generator(train_data,
                              epochs=25,
                              validation_data=test_data,
                              validation_steps=test_data.samples//batch_size,
                              steps_per_epoch=train_data.samples//batch_size,
                              callbacks=callbacks)
# Out:
# WARNING:tensorflow:From <ipython-input-14-4a393af70979>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 625 steps, validate for 156 steps
# Epoch 1/25
# 625/625 [==============================] - 117s 187ms/step - loss: 0.6967 - accuracy: 0.5306 - val_loss: 0.6881 - val_accuracy: 0.5371
# Epoch 2/25
# 625/625 [==============================] - 98s 157ms/step - loss: 0.6816 - accuracy: 0.5635 - val_loss: 0.6705 - val_accuracy: 0.5895
# Epoch 3/25
# 625/625 [==============================] - 99s 159ms/step - loss: 0.6707 - accuracy: 0.5890 - val_loss: 0.6505 - val_accuracy: 0.6148
# Epoch 4/25
# 625/625 [==============================] - 100s 160ms/step - loss: 0.6617 - accuracy: 0.6021 - val_loss: 0.6372 - val_accuracy: 0.6390
# Epoch 5/25
# 625/625 [==============================] - 99s 159ms/step - loss: 0.6419 - accuracy: 0.6314 - val_loss: 0.6174 - val_accuracy: 0.6737
# Epoch 6/25
# 625/625 [==============================] - 101s 161ms/step - loss: 0.6125 - accuracy: 0.6651 - val_loss: 0.5567 - val_accuracy: 0.7163
# Epoch 7/25
# 625/625 [==============================] - 101s 161ms/step - loss: 0.5884 - accuracy: 0.6924 - val_loss: 0.5414 - val_accuracy: 0.7292
# Epoch 8/25
# 625/625 [==============================] - 99s 158ms/step - loss: 0.5601 - accuracy: 0.7139 - val_loss: 0.5409 - val_accuracy: 0.7210
# Epoch 9/25
# 625/625 [==============================] - 98s 157ms/step - loss: 0.5424 - accuracy: 0.7261 - val_loss: 0.5045 - val_accuracy: 0.7620
# Epoch 10/25
# 625/625 [==============================] - 99s 158ms/step - loss: 0.5166 - accuracy: 0.7485 - val_loss: 0.5039 - val_accuracy: 0.7498
# Epoch 11/25
# 625/625 [==============================] - 100s 160ms/step - loss: 0.4989 - accuracy: 0.7592 - val_loss: 0.4766 - val_accuracy: 0.7726
# Epoch 12/25
# 625/625 [==============================] - 100s 159ms/step - loss: 0.4846 - accuracy: 0.7671 - val_loss: 0.4575 - val_accuracy: 0.7845
# Epoch 13/25
# 625/625 [==============================] - 99s 158ms/step - loss: 0.4761 - accuracy: 0.7735 - val_loss: 0.4564 - val_accuracy: 0.7796
# Epoch 14/25
# 625/625 [==============================] - 97s 156ms/step - loss: 0.4595 - accuracy: 0.7852 - val_loss: 0.4388 - val_accuracy: 0.7943
# Epoch 15/25
# 625/625 [==============================] - 97s 155ms/step - loss: 0.4490 - accuracy: 0.7940 - val_loss: 0.4264 - val_accuracy: 0.7985
# Epoch 16/25
# 625/625 [==============================] - 106s 169ms/step - loss: 0.4412 - accuracy: 0.7954 - val_loss: 0.4253 - val_accuracy: 0.8007
# Epoch 17/25
# 625/625 [==============================] - 99s 158ms/step - loss: 0.4293 - accuracy: 0.8031 - val_loss: 0.4286 - val_accuracy: 0.7989
# Epoch 18/25
# 625/625 [==============================] - 99s 158ms/step - loss: 0.4184 - accuracy: 0.8090 - val_loss: 0.4107 - val_accuracy: 0.8115
# Epoch 19/25
# 625/625 [==============================] - 100s 160ms/step - loss: 0.4040 - accuracy: 0.8161 - val_loss: 0.3667 - val_accuracy: 0.8327
# Epoch 20/25
# 625/625 [==============================] - 99s 158ms/step - loss: 0.4016 - accuracy: 0.8202 - val_loss: 0.3627 - val_accuracy: 0.8383
# Epoch 21/25
# 625/625 [==============================] - 98s 156ms/step - loss: 0.3948 - accuracy: 0.8234 - val_loss: 0.3625 - val_accuracy: 0.8345
# Epoch 22/25
# 625/625 [==============================] - 99s 159ms/step - loss: 0.3846 - accuracy: 0.8296 - val_loss: 0.3780 - val_accuracy: 0.8281
# Epoch 23/25
# 625/625 [==============================] - 101s 161ms/step - loss: 0.3797 - accuracy: 0.8278 - val_loss: 0.3763 - val_accuracy: 0.8333
# Epoch 24/25
# 625/625 [==============================] - 100s 160ms/step - loss: 0.3729 - accuracy: 0.8359 - val_loss: 0.3656 - val_accuracy: 0.8427
# Epoch 25/25
# 625/625 [==============================] - 99s 159ms/step - loss: 0.3710 - accuracy: 0.8355 - val_loss: 0.3683 - val_accuracy: 0.8259

# %%
model.save('model.h5')

# %% [markdown]
# ### Plot history

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 15))
ax[0].plot(results.history['accuracy'], label='Train accuracy')
ax[0].plot(results.history['val_accuracy'], label='Validation accuracy')
ax[0].legend(['Train accuracy', 'Validation accuracy'])

ax[1].plot(results.history['loss'], label='Train loss')
ax[1].plot(results.history['val_loss'], label='Validation loss')
ax[1].legend(['Train loss', 'Validation loss'])

plt.show()

# %% [markdown]
# ### Get result

# %%
test_filenames = os.listdir('dataset/test/test')
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
test_gen = ImageDataGenerator(rescale=1./255)

test_set = test_gen.flow_from_dataframe(
    test_df,
    'dataset/test/test',
    target_size=image_shape[:2],
    batch_size=batch_size,
    x_col='filename',
    y_col=None,
    class_mode=None,
    shuffle=False
)
# Out:
# Found 12500 validated image filenames.

# %%
predictions = model.predict_generator(test_set)
# Out:
# WARNING:tensorflow:From <ipython-input-19-cd9fe42a2af9>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
test_df['label'] = np.argmax(predictions, axis=1)

# %%
test_df['id'] = test_df['filename'].str.split('.').str[0]
test_df = test_df.drop('filename', axis=1)

# %%
test_df.to_csv(path_or_buf='result.csv', index=False)
